# %%
import os, sys
sys.path.append('../')
from tqdm import tqdm
import random
from env.env import *
from algorithms.ucrl2_hard import *
from algorithms.optimal_policy import *

import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(os.getcwd())
print(os.listdir())
# Out:
# c:\Users\codnw\PycharmProjects\linear_mixture_mdp\LSVI-DC\search
# ['.ipynb_checkpoints', 'Optimal.ipynb', 'Optimal_hard.ipynb', 'TSDE.ipynb', 'UCMLK.ipynb', 'UCMLK_hard.ipynb', 'UCRL-MNL.ipynb', 'UCRL2-VTR.ipynb', 'UCRL2-VTR_hard.ipynb', 'UCRL2.ipynb', 'UCRL2_hard.ipynb']

# %%
nState = 2
T = 500

# env = make_riverSwim(T=T, nState=nState)
# env = make_randomMDP(T=Round, nState=7, nAction=2, reward_range=(0,1), sparsity=0.3)
env = make_hardToLearnMDP(T=T)
runs = 10
seeds = [1234*(i+1) for i in range(runs)]

# %%
run_returns = []

for run in tqdm(range(runs)):
    
    random.seed(seeds[run])

    agent = UCRL2(env, T=T, delta=0.1)
    episodic_return = agent.run()
    run_returns.append(episodic_return)
#     np.save('../data/exp1/UCMLK/return'+str(run)+'.npy', episodic_return)
    np.save('../data/hardtolearn/S=' + str(nState)+ ', T=' + str(T) +'/UCRL2/return'+str(run)+'.npy', episodic_return)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# UCRL2
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
# 0.3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       5     random.seed(seeds[run])
#       7     agent = UCRL2(env, T=T, delta=0.1)
# ----> 8     episodic_return = agent.run()
#       9     run_returns.append(episodic_return)
#      10 #     np.save('../data/exp1/UCMLK/return'+str(run)+'.npy', episodic_return)
#
# File c:\Users\codnw\PycharmProjects\linear_mixture_mdp\LSVI-DC\search\..\algorithms\ucrl2_hard.py:141, in UCRL2.run(self)
#     136 else:
#     137     # a = self.act(s, pi_tilde)
#     138     # a = self.act(s, u)
#     139     a = pi_tilde[s]
# --> 141 r, s_ = self.env.advance(a)
#     142 R += r
#     144 self.N_sa[s][a] += 1
#
# File c:\Users\codnw\PycharmProjects\linear_mixture_mdp\LSVI-DC\search\..\env\env.py:235, in TabularMDP.advance(self, action)
#     233 #print(self.state, action, self.P[self.state, action])
#     234 print(self.P[self.state, action])
# --> 235 newState = np.random.choice(self.nState, p=self.P[self.state, action])
#     236 # Update the environment
#     237 self.state = newState
#
# File numpy\\random\\mtrand.pyx:977, in numpy.random.mtrand.RandomState.choice()
#
# TypeError: object of type 'float' has no len()

# %%
episodes = np.arange(T)

plt.figure()
data_mean = np.mean(run_returns, axis=0)
data_std = np.std(run_returns, axis=0)
    
plt.fill_between(episodes, data_mean + data_std, data_mean - data_std, alpha=0.2)
plt.plot(episodes, data_mean, linewidth=1.8)
plt.title("RiverSwim: nState=4, epLen=15")
plt.xlabel("The Number of Episodes")

plt.ylabel("Episodic Returns")
plt.show()
